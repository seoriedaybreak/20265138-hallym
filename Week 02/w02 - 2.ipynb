# %%
price = int(input('상품 가격을 입력하세요: '))
discount_rate = float(input('0~1 사이 할인율을 입력하세요:'))
total= price - (price * discount_rate)
print('할인된 가격은 ', int(total), '원 입니다')
# Out:
# 할인된 가격은  950 원 입니다

# %%
msg = 'Merry Christmas!'
len(msg)
# Out:
# 16

# %%
msg = 'Merry Christmas!'
msg.upper()
# Out:
# 'MERRY CHRISTMAS!'

# %%
msg = 'Merry Christmas!'
msg.lower()
# Out:
# 'merry christmas!'

# %%
string = 'python string'
print(string[0], string[4], string[-6], string[-10])

print(string[0:4])
print(string[-10:-4])
print(string[:7])
print(string[-4:])
# Out:
# p o s h
# pyth
# hon st
# python
# ring

# %%
print('The harder you work, \n\nthe more likely \tyoucan reach the goal')
# Out:
# The harder you work,
#
# the more likely 	youcan reach the goal

# %%
ftemp = int(input('화씨 온도를 입력하세요: '))
ctemp = (ftemp - 32) * 5 / 9
print(f'섭씨 온도는 {ctemp}도 입니다')
# Out:
# 섭씨 온도는 37.77777777777778도 입니다

# %%
msg = 'hello'
print(f'{msg:<10}')
print(f'{msg:>10}')
print(f'{msg:^10}')
# Out:
# hello
#      hello
#   hello
