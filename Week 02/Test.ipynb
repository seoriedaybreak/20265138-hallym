# %%
print('Hello Python~!')
# Out:
# Hello Python~!

# %%
print(20//4)
print(20%3)  # //은 나누기의 몫 / %은 나누기의 나머지
# Out:
# 5
# 2

# %%
30*2    # *은 곱하기
# Out:
# 60

# %%
print('Hello Python!')
# Out:
# Hello Python!
